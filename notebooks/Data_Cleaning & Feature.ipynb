# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\vchan\OneDrive\Desktop\AI_Student\data\ai_assistant_usage_student_life.csv")

# %%
df.head(10)
# Out:
#       SessionID   StudentLevel        Discipline SessionDate  \
# 0  SESSION00001  Undergraduate  Computer Science  2024-11-03
# 1  SESSION00002  Undergraduate        Psychology  2024-08-25
# 2  SESSION00003  Undergraduate          Business  2025-01-12
# 3  SESSION00004  Undergraduate  Computer Science  2025-05-06
# 4  SESSION00005  Undergraduate        Psychology  2025-03-18
# 5  SESSION00006       Graduate          Business  2025-01-17
# 6  SESSION00007    High School           Biology  2024-09-07
# 7  SESSION00008  Undergraduate           Biology  2024-12-26
# 8  SESSION00009  Undergraduate          Business  2025-06-18
# 9  SESSION00010  Undergraduate              Math  2025-04-14
#
#    SessionLengthMin  TotalPrompts       TaskType  AI_AssistanceLevel  \
# 0             31.20            11       Studying                   2
# 1             13.09             6       Studying                   3
# 2             19.22             5         Coding                   3
# ...

# %% [markdown]
# ## Understanding Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SessionID           10000 non-null  object
#  1   StudentLevel        10000 non-null  object
#  2   Discipline          10000 non-null  object
#  3   SessionDate         10000 non-null  object
#  4   SessionLengthMin    10000 non-null  float64
#  5   TotalPrompts        10000 non-null  int64
#  6   TaskType            10000 non-null  object
#  7   AI_AssistanceLevel  10000 non-null  int64
#  8   FinalOutcome        10000 non-null  object
#  9   UsedAgain           10000 non-null  bool
#  10  SatisfactionRating  10000 non-null  float64
# dtypes: bool(1), float64(2), int64(2), object(6)
# memory usage: 791.1+ KB

# %%
df.isnull().sum()
# Out:
# SessionID             0
# StudentLevel          0
# Discipline            0
# SessionDate           0
# SessionLengthMin      0
# TotalPrompts          0
# TaskType              0
# AI_AssistanceLevel    0
# FinalOutcome          0
# UsedAgain             0
# SatisfactionRating    0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#            SessionID   StudentLevel Discipline SessionDate  SessionLengthMin  \
# count          10000          10000      10000       10000      10000.000000
# unique         10000              3          7         366               NaN
# top     SESSION09984  Undergraduate    Biology  2025-01-19               NaN
# freq               1           5978       1458          41               NaN
# mean             NaN            NaN        NaN         NaN         19.846467
# std              NaN            NaN        NaN         NaN         13.897302
# min              NaN            NaN        NaN         NaN          0.030000
# 25%              NaN            NaN        NaN         NaN          9.630000
# 50%              NaN            NaN        NaN         NaN         16.650000
# 75%              NaN            NaN        NaN         NaN         26.670000
# max              NaN            NaN        NaN         NaN        110.810000
#
# ...

# %% [markdown]
# ## Changing Date column dtype

# %%
df['SessionDate'] = pd.to_datetime(df['SessionDate'])

# %%
df['SessionDate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10000 entries, 0 to 9999
# Series name: SessionDate
# Non-Null Count  Dtype
# --------------  -----
# 10000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 78.2 KB

# %% [markdown]
# ## Feature Engineering Year and Month

# %%
df['Year'] = df['SessionDate'].dt.year
df['Month'] = df['SessionDate'].dt.month

# %%
df
# Out:
#          SessionID   StudentLevel        Discipline SessionDate  \
# 0     SESSION00001  Undergraduate  Computer Science  2024-11-03
# 1     SESSION00002  Undergraduate        Psychology  2024-08-25
# 2     SESSION00003  Undergraduate          Business  2025-01-12
# 3     SESSION00004  Undergraduate  Computer Science  2025-05-06
# 4     SESSION00005  Undergraduate        Psychology  2025-03-18
# ...            ...            ...               ...         ...
# 9995  SESSION09996  Undergraduate        Psychology  2024-07-20
# 9996  SESSION09997    High School          Business  2024-11-11
# 9997  SESSION09998  Undergraduate           Biology  2024-09-11
# 9998  SESSION09999  Undergraduate          Business  2024-10-27
# 9999  SESSION10000  Undergraduate              Math  2025-04-16
#
#       SessionLengthMin  TotalPrompts  TaskType  AI_AssistanceLevel  \
# 0                31.20            11  Studying                   2
# ...
